# %% [markdown]
# # Today's Agenda
# - Dictionary
# > ### What is Dictionary?
# > ### Different ways of creating Dictionary?
# > ### How to call Dictionary elements?
# > ### How to apply different Dictionary operations?
# > ### What are the built-in functions availble in Dictionary!
# > ### How it is different from the set?

# %% [markdown]
# **A Python dictionary is a data structure that stores key/value pairs. Each element of a Python dictionary is a key/value pair. The keys are like an index operator. In a list, the indexes are integers. In a dictionary, the key must be a hashable object. A dictionary cannot contain duplicate keys. Each key maps to one value. A key and its corresponding value form an item (or entry) stored in a dictionary. The data structure is a called a “dictionary” because it resembles a word dictionary, where the words are the keys and the words’ definitions are the values. A dictionary is also known as a map, which maps each key to a value. It enables fast retrieval, deletion, and updating of the value by using the key.**

# %% [markdown]
# - Dictionaries are a collection in python which consists of key-value pairs
# - Dictionaries are unordered, non-indexable and mutable
# - Dictionaries are defined using `{}`
# - Dictionaries don't allow duplicate keys

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Creating a Dictionary
# - You can create a dictionary by enclosing the items inside a pair of curly braces ({}). Each item consists of a key, followed by a colon, followed by a value. The items are separated by commas.

# %% [markdown]
# **You can create an empty dictionary by using the following syntax:**

# %%
# Empty Dictionary without value
empty_students = {}
print(empty_students)
print(type(empty_students))
print(len(empty_students))
# dictionary object: students
# Out:
# {}
# <class 'dict'>
# 0

# %%
# Dictionary with student name and roll no
batch_516 = {1 : "Sai", 2 : "Kiran"}
batch_516
# Out:
# {1: 'Sai', 2: 'Kiran'}

# %% [markdown]
# **Note:Python uses curly braces for sets and dictionaries. The syntax {} denotes an empty dictionary.To create an empty set, use set()**

# %% [markdown]
# # 2. Adding, Modifying, and Retrieving Values

# %%
# adding
batch_516 = {1 : "Sai", 2 : "Kiran"}
batch_516[3] = 'sai'
batch_516
# Out:
# {1: 'Sai', 2: 'Kiran', 3: 'sai'}

# %%
# Modifying or Update
batch_516[1] = "Vamsi"
print(batch_516)
# Out:
# {1: 'Vamsi', 2: 'Kiran', 3: 'sai'}

# %%
# retrieving
batch_516[3]
# Out:
# 'sai'

# %%
# Accessing key that is absent
batch_516[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Accessing key that is absent
# ----> 2 batch_516[4]
#
# KeyError: 4

# %% [markdown]
# ### get()
# - To prevent a KeyError exception, we can use the get() function on a dictionary. Then, if a value is not found for a given key, it returns nothing (and otherwise returns the value associated with that key).
# - To continue program execution.

# %%
batch_516.get(3)
# Out:
# 'sai'

# %%
# No key : None Output
batch_516.get(4) # 4 is not a key value. it dont get an error.

# %%
# No key : None Output
batch_516.get("Kiran")  # Kiran is there in the dictionary. But this is not a key. 
                        # So it will not get an output. Instead of a value, you can call a key.

# %% [markdown]
# # 3. Getting all
# - ### keys()
# - ### values()
# - ### items()
#
#
# - While calling keys or values or items are should be a list.
# - and when calling items should be tuple inside a list.

# %% [markdown]
# ### 1. Keys()

# %%
# Keys
keys = batch_516.keys()
print(keys)
print(type(keys))
# Out:
# dict_keys([1, 2, 3])
# <class 'dict_keys'>

# %% [markdown]
# ### 2. values()

# %%
# Values
values = batch_516.values()
print(values)
print(type(values))
# Out:
# dict_values(['Vamsi', 'Kiran', 'sai'])
# <class 'dict_values'>

# %% [markdown]
# ### 3. items()

# %%
# Items
items = batch_516.items()
print(items)
print(type(items))
# Out:
# dict_items([(1, 'Vamsi'), (2, 'Kiran'), (3, 'sai')])
# <class 'dict_items'>

# %% [markdown]
# # 4. Common operations
# - in
# - not in
# - ==
# - !=

# %%
# length of dictionary
len(batch_516)
# Out:
# 3

# %%
lst = ["vamsi", "sai", "Kiran"]
"Kiran" in lst
# Out:
# True

# %%
# We cann not check membership of a value
"kiran" in batch_516
# Out:
# False

# %%
# Can check membership of a key
1 in batch_516
# Out:
# True

# %%
print(batch_516)
batch_516['4'] = 'Kiran'
print(batch_516)
# Out:
# {1: 'Vamsi', 2: 'Kiran', 3: 'sai'}
# {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}

# %% [markdown]
# ### **== Operator**

# %%
# Compare the values of a dictionary
batch_516['1'] == batch_516['2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Compare the values of a dictionary
# ----> 2 batch_516['1'] == batch_516['2']
#
# KeyError: '1'

# %%
dict1 = {'name':'sai', 'age' : 21}
dict2 = {'age' : 21, 'sai' : 'name'}
dict3 = {'age' : 21, 'name' : 'kiran'}
dict4 = {'age' : 21, 'name' : 'sai'}

print(dict1 == dict2)
print(dict1 != dict2)
print(dict1 == dict3)
print(dict1 == dict4)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Note :**
#
# - We comparing the **values** not the keys.
# - **Membership Operator** checks **keys**.  (in / not in)
# - **Comparison Operator** compares **Values**. ( == ) only.

# %% [markdown]
# **You cannot use the comparison operators (>, >=, <=, and <) to compare dictionaries because the items are not ordered.**

# %% [markdown]
# # 5.Removing values from a dictionary

# %% [markdown]
# ### pop()
# - remove the key-value pair

# %%
print(batch_516)
# Out:
# {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}

# %%
batch_516.pop(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 batch_516.pop(3)
#
# NameError: name 'batch_516' is not defined

# %%
batch_516 = {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}
print(batch_516)
print(batch_516.pop('3'))
# Out:
# {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 3
#       1 batch_516 = {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}
#       2 print(batch_516)
# ----> 3 print(batch_516.pop('3'))
#
# KeyError: '3'

# %% [markdown]
# ### popitem()
# - to remove the last key-value pair

# %%
print(batch_516)
print(batch_516.popitem())  # It pop the end item
# Out:
# {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}
# ('4', 'Kiran')

# %% [markdown]
# ### del
# - using `del` to remove ('Blood group','A-')

# %%
batch_516 = {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}
print(batch_516)
del(batch_516['1'])
print(batch_516)
# Out:
# {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 3
#       1 batch_516 = {1: 'Vamsi', 2: 'Kiran', 3: 'sai', '4': 'Kiran'}
#       2 print(batch_516)
# ----> 3 del(batch_516['1'])
#       4 print(batch_516)
#
# KeyError: '1'

# %%
del(batch_516)
batch_516   # Delete entire data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 del(batch_516)
# ----> 2 batch_516   # Delete entire data
#
# NameError: name 'batch_516' is not defined

# %% [markdown]
# # 6.Some dictionary methods

# %% [markdown]
# ### fromkeys()

# %%
# Using dict keyword
# Create a list of keys
keys = ['a', 'b', 'c']
values = [1,2,3]

dict.fromkeys(keys, values)
# Out:
# {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': [1, 2, 3]}

# %%
# Using empty dictionary
dicts = {}
dicts.fromkeys(keys, values)
# Out:
# {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': [1, 2, 3]}

# %%
# Does not Update automatically
dicts
# Out:
# {}

# %%
# Reassign to same or different variable
dicts = dicts.fromkeys(keys,values)
dicts
# Out:
# {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': [1, 2, 3]}

# %%
# Using dict keyword
# Create a list of keys
keys = ['a', 'b', 'c']
values = 1

dict.fromkeys(keys, values)
# Out:
# {'a': 1, 'b': 1, 'c': 1}

# %%
dicts = {}
dicts = dicts.fromkeys(keys, values)
dicts
# Out:
# {'a': 1, 'b': 1, 'c': 1}

# %%
keys = ['c', 'd']
value = 20
dict2 = dict.fromkeys(keys, value)
dict2
# Out:
# {'c': 20, 'd': 20}

# %% [markdown]
# ### unpacking

# %%
# Frome multiple dictionary to a single dictionary

{**dict2, **dicts}   #  ** : are Wird characters
# Out:
# {'c': [1, 2, 3], 'd': 20, 'a': [1, 2, 3], 'b': [1, 2, 3]}

# %%
{**dicts, **dict2}
# Out:
# {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': 20, 'd': 20}

# %%
dict3 = {**dict2, **dicts}   
print(dict3)
# Out:
# {'c': [1, 2, 3], 'd': 20, 'a': [1, 2, 3], 'b': [1, 2, 3]}

# %%
dict3 = {**dicts, **dict2}   
print(dict3)
# Out:
# {'a': [1, 2, 3], 'b': [1, 2, 3], 'c': 20, 'd': 20}

# %%
dict3.items()
# Out:
# dict_items([('a', [1, 2, 3]), ('b', [1, 2, 3]), ('c', 20), ('d', 20)])

# %%
# Only Keys
for item in dict3:
    print(item)
# Out:
# a
# b
# c
# d

# %%
for key,value in dict3.items():
    print(key,value)
# Out:
# a [1, 2, 3]
# b [1, 2, 3]
# c 20
# d 20

# %%
for key,value in dict3.items():
    print(key)
# Out:
# a
# b
# c
# d

# %%
for key,value in dict3.items():
    print(value)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# 20
# 20
