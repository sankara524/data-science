# %% [markdown]
# ### Task-1

# %% [markdown]
# #### Q1. Define and print a variable
# #### Create a variable name and assign your name to it. Print the value of the variable.

# %%
name = "Saikiran"
print(name)
# Out:
# Saikiran

# %% [markdown]
# #### Q2. Multiple variable assignments.
# ####  Assign the values 10, 20, and 30 to variables a, b, and c in a single line. Print all three variables.

# %%
a,b,c = 10, 20, 30
print(a,b,c)
# Out:
# 10 20 30

# %% [markdown]
# #### Q3. Swap two variables
# #### Create variables x = 5 and y = 10. Swap their values without using a third variable and print the result.

# %%
x = 5
y = 10
x, y = y,x
print(x, y)
# Out:
# 10 5

# %% [markdown]
# ##### Q4. Valid vs Invalid Identifiers
# ##### Write 5 examples of valid Python identifiers and 5 examples of invalid identifiers. Explain why the invalid ones are not allowed.

# %% [markdown]
# #### Valid Identifier

# %%
num = 10
age = 23
name = "Sai Kiran"
first_name = "Sankara"
exact_age = 23.8
print(num, age, name, first_name, exact_age ,sep="\n")
# Out:
# 10
# 23
# Sai Kiran
# Sankara
# 23.8

# %% [markdown]
# #### Invalid Identifier

# %%
# Note: We should not use keywords as a identifier
# Should not start a variable with numbers
# Should not split with spaces

# %%
1stone = "Sai Kiran"
for = "Consider as invalid"
in = "means its in inside"
first name = "Sai Kiran"
type() = "integer"
# Out:
#   Cell In[9], line 1
#     1stone = "Sai Kiran"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ##### Q5. Variable naming rules
# ##### Create three variables following Python naming rules and print them.

# %%
var_one = 1
var_two = 2
var_three = 3
print(var_one, var_two, var_three)
# Out:
# 1 2 3

# %% [markdown]
# ##### Q6. Assign different data types
# ##### Assign the following to variables and print their types:
# ##### An integer
# ##### A float
# ##### A string
# ##### A boolean

# %%
integer = 100
float_number = 20.2
String = "Hi"
bool_value = True

print(integer, type(integer))
print(float_number, type(float_number))
print(String, type(String))
print(bool_value, type(bool_value))
# Out:
# 100 <class 'int'>
# 20.2 <class 'float'>
# Hi <class 'str'>
# True <class 'bool'>

# %% [markdown]
# ##### Q7. Dynamic typing
# ##### Assign an integer to a variable num. Then reassign a string to the same variable. Print the value and type each time.

# %%
num = 100
print(num, type(num))

# Re Assign
num = str(num)
print(num, type(num))
# Out:
# 100 <class 'int'>
# 100 <class 'str'>

# %% [markdown]
# ##### Q8. Create a variable city and assign it the value "Bangalore". Then create another variable population with value 12000000. Print both variables in a single line separated by a comma.
# ##### Input:
# ##### city = "Bangalore"
# ##### population = 12000000
# ##### Output:
# ##### Bangalore, 12000000

# %%
city = "Bengalore"
population = 12000000
print(city, ',', population)
# Out:
# Bengalore , 12000000

# %% [markdown]
# ##### Q9. Create a variable language = "Python" and another variable version = 3.10. Print a sentence combining both variables like: "Python version is 3.10".
# ##### Input:
# ##### language = "Python"
# ##### version = 3.10
# ##### Output:
# ##### Python version is 3.10

# %%
language = "Python"
version = "3.10"
print(language, "version is =" , version)
# Out:
# Python version is = 3.10

# %% [markdown]
# ##### Q10. Concatenate variables
# ##### Create two string variables first_name = "John" and last_name = "Doe". Concatenate them into a new variable full_name and print it.

# %%
first_name = "John"
last_name = "Doe"
print(first_name, last_name)
# Out:
# John Doe
