# %% [markdown]
# ### Task-2 (Python Operators)

# %% [markdown]
# ### 1. Arithmetic Operators

# %% [markdown]
# #### 1. Write a Python program to add two numbers using the + operator.

# %%
num1 = 100
num2 = 100
print(num1 + num2)
# Out:
# 200

# %% [markdown]
# #### 2. Write a program to subtract b from a.

# %%
a = 50
b = 20
print(a - b)
# Out:
# 30

# %% [markdown]
# #### 3. Write a Python program to multiply two numbers.

# %%
num1 = 10
num2 = 20
print(num1*num2)
# Out:
# 200

# %% [markdown]
# #### 4. Divide 25 by 4 and display both normal division (/) and floor division (//) results.

# %%
num1 = 25
num2 = 4
print("Division:", num1/num2)
print("Floor Division:", num1//num2)
# Out:
# Division: 6.25
# Floor Division: 6

# %% [markdown]
# #### 5. Write a program to find the remainder when 17 is divided by 3.

# %%
num1 = 17
num2 = 3
print(num1 % num2)
# Out:
# 2

# %% [markdown]
# #### 6. Find the result of 5 ** 3 and explain what it represents.

# %%
num1 = 5
num2 = 3
print(num1**num2)  # 5 ** 3 that is 5 cube (5*5*5 = 125)
# Out:
# 125

# %% [markdown]
# #### 7. If a = 10, b = 4, find and print all arithmetic results (+, -, *, /, %, //, **).

# %%
a = 10
b = 4
print("10 + 4 =",a + b)
print("10 - 4 =",a - b)
print("10 * 4 =",a * b)
print("10 / 4 =", a / b)
print("10 % 4 =", a % b)
print("10 // 4 =", a // b)
print("10 ** 4 =", a ** b)
# Out:
# 10 + 4 = 14
# 10 - 4 = 6
# 10 * 4 = 40
# 10 / 4 = 2.5
# 10 % 4 = 2
# 10 // 4 = 2
# 10 ** 4 = 10000

# %% [markdown]
# ### 2. Assignment Operators

# %% [markdown]
# #### 1. Write a Python program to show how += works. Example: x += 3.

# %%
x = 5
x += 3  # x = x + 3
print(x)
# Out:
# 8

# %% [markdown]
# #### 2. Demonstrate the use of -= operator.

# %%
# Example program
a = 10
a -= 2  # (a = a - 2) subtracts the value on the right from the variable on the left, then assigns the result back to that variable.
print(a)
# Out:
# 8

# %% [markdown]
# #### 3. Write a program where x = 10, and you apply x*= 5. Print the new value of x

# %%
x = 10
x *= 5
print(x)
# Out:
# 50

# %% [markdown]
# #### 4. Use /= operator to divide a number by 4.

# %%
a = 10
a /= 4
print(a)
# Out:
# 2.5

# %% [markdown]
# #### 5. Write a small code showing the working of %= operator.

# %%
x = 100
x %= 22  # x = x % 22
print(x)
# Out:
# 12

# %% [markdown]
# #### 6. Show an example using //=, and print before and after values of the variable.

# %%
x = 7
x /= 3
print("Division=", x)

x = 7
x //= 3
print("Floor Divsion=", x)
# Out:
# Division= 2.3333333333333335
# Floor Divsion= 2

# %% [markdown]
# #### 7. Write code demonstrating the use of **= for squaring a number.

# %%
x = 3
x **= 3
print(x)
# Out:
# 27

# %% [markdown]
# ### 3. Comparison (Relational) Operators

# %% [markdown]
# #### 1. Write a program to check if two numbers are equal using ==.

# %%
num1 = 20
num2 = 20
print(num1 == num2)
# Out:
# True

# %% [markdown]
# #### 2. Write a code to check if a number is not equal to another using !=.

# %%
num1 = 20
num2 = 20
print(num1 != num2)
# Out:
# False

# %% [markdown]
# #### 3. Write a program that takes two numbers and prints whether the first is greater than the second.

# %%
num1 = 20
num2 = 10
print(num1 > num2)
# Out:
# True

# %% [markdown]
# #### 4. Write a program using < and > to compare user inputs.

# %%
num1 = 20
num2 = 10
print(num1 > num2)
print(num2 < num2)
# Out:
# True
# False

# %% [markdown]
# #### 5. Demonstrate the use of >= and <= operators with examples.

# %%
num1 = 20 
num2 =10
print(num1 >= num2)
print(num1 <= num2)
# Out:
# True
# False

# %% [markdown]
# #### 6. Write a program that checks whether a given number is between 10 and 20 (inclusive).

# %%
a = 10
b = 20
c = 19
print(c >= a and c <= b)
# Out:
# True

# %% [markdown]
# #### 7. Write a code to compare two strings "apple" and "banana" using < and explain the output.

# %%
Str1 = "apple"
Str2 = "banana"
print(Str1 < Str2)
# Out:
# True

# %% [markdown]
# ### 4. Logical Operators

# %% [markdown]
# #### 1. Write a program using and operator to check if a number is between 1 and 10.

# %%
x = 1
y = 10
z = 8
print(z >= x and z <= y)
# Out:
# True

# %% [markdown]
# #### 2. Use or operator to check if a number is less than 5 or greater than 15.

# %%
a = 6
print(a < 5 or a > 15)
# Out:
# False

# %% [markdown]
# #### 3. Demonstrate the use of not operator to reverse a condition.

# %%
print(5 == 5)
print(not 5 == 5)
# Out:
# True
# False

# %% [markdown]
# #### 4. Predict the output:
# #### a = 5
# #### print(a > 2 and a < 10)

# %%
a = 5
print(a > 2 and a < 10)
# Out:
# True

# %% [markdown]
# #### 5. Predict the output:
# #### x = 3
# #### print(x < 2 or x == 3)

# %%
x = 3
print(x < 2 or x == 3)
# Out:
# True

# %% [markdown]
# #### 6. Write a small program that takes a user’s age and prints if the person is a teenager (13–19) using and.

# %%
a = 18
print(a >= 13 and a <= 19)
# Out:
# True

# %% [markdown]
# ### 5. Identity Operators

# %% [markdown]
# #### 1. Write a program using is to check if two variables refer to the same object.

# %%
a = 10
b = 10
print(a is b)
# Out:
# True

# %% [markdown]
# ### 2. Demonstrate the use of is not operator.

# %%
# When ever the two numbers are same it will show Error.
# is not operator is a reverse of equal operator.

# Example:

a = 10
b = 10
print(a is not b)

# %% [markdown]
# ### 3. Explain the difference between == and is with an example.

# %%
# == : two objects have the same values are true else false.
# is : Both variables point to the same object in memory the result is true else false.

# Example for '=='
a = 10
b = 10
print(a == b)
print(a is b)

# Example for 'is'
a = [1,2,3]
b = [1,2,3]
print(a is b)
print(a == b)
# Out:
# True
# True
# False
# True

# %% [markdown]
# ### 6. Membership Operators

# %% [markdown]
# #### 1. Write a program to check if 'a' is present in the string "banana".

# %%
String = "banana"
print("a" in String)
# Out:
# True

# %% [markdown]
# #### 2. Write a program to check if 5 is in the list [1, 2, 3, 4, 5].

# %%
list = [1,2,3,4,5]
print(5 in list)
# Out:
# True

# %% [markdown]
# #### 3. Use not in to check if 'cat' is not present in the list ['dog', 'bat', 'rat'].

# %%
String = ["dog", "bat", "rat"]
print("cat" not in String)
# Out:
# True

# %% [markdown]
# #### 4. Write a small program where the user enters a number, and you check if it is in [10, 20, 30, 40].

# %%
num = [10, 20, 30, 40]
print(0 in num)
# Out:
# False

# %% [markdown]
# ### 7. Bitwise Operators

# %% [markdown]
# #### 1. Write a program using & (bitwise AND) for two numbers.

# %%
a = 10
b = 10
print(a & b)
# Out:
# 10

# %% [markdown]
# #### 2. Demonstrate bitwise | (OR) between 12 and 7.

# %%
a = 10
b = 10
print(a | b)
# Out:
# 10

# %% [markdown]
# #### 3. Write a code to perform bitwise XOR (^) operation.

# %%
a = 10
b = 10
print(a ^ b)
# Out:
# 0

# %% [markdown]
# #### 4. Write a program using bitwise NOT (~) on a number and explain the result.

# %%
a = 10
print( ~ a)
# Out:
# -11

# %% [markdown]
# #### 5. Demonstrate left shift (<<) operator with x = 5.

# %%
x = 5
print(x<<5)
# Out:
# 160

# %% [markdown]
# #### 6. Demonstrate right shift (>>) operator with x = 20.

# %%
x = 20
print(x >> x)
# Out:
# 0

# %% [markdown]
# #### 7. Combine multiple bitwise operations in one expression and print result.

# %%
a = 5
b = 4
expression = (a & b) & (a ^ b) | (~a)
print(expression)
# Out:
# -6

# %% [markdown]
# #### 8. Predict the output of:
# #### x = 10
# #### y = 4
# #### print(x & y, x | y, x ^ y, ~x)

# %%
x = 10
y = 4
print(x & y, x | y, x ^ y, ~x)
# Out:
# 0 14 14 -11

# %% [markdown]
# ### 8. Operator Precedence

# %% [markdown]
# #### 1. Predict the output of print(10 + 3 * 2).

# %%
print(10 + 3 * 2)
# Out:
# 16

# %% [markdown]
# #### 2. Predict the output of print((10 + 3) * 2).

# %%
print((10 + 3) * 2)
# Out:
# 26

# %% [markdown]
# #### 3. Write a small code showing how parentheses () change the evaluation order.

# %%
print(22 + 8 * 9)

print((22 + 8) * 9)
# Out:
# 94
# 270

# %% [markdown]
# #### 4. Predict output:
# #### print(2 ** 3 ** 2) (Hint: Right-to-left precedence)

# %%
print(2 ** 3 ** 2)
# Out:
# 512

# %% [markdown]
# #### 5. Write a program combining arithmetic, comparison, and logical operators and explain the order in which they are executed.

# %%
a = 2
b = 4
print((a + b * a) > 10 and (a - b) < 10 or not(c == 2))
# Out:
# True
