# %% [markdown]
# ## **Task-3 (String Methods, Slicing, and Indexing)**

# %% [markdown]
# ### 1. Find length of a string

# %%
string = "Hello World"
len(string)
# Out:
# 11

# %%
string = "Python"
len(string)
# Out:
# 6

# %%
string = "  "
len(string)
# Out:
# 2

# %% [markdown]
# ### 2. Convert a string to uppercase

# %%
string = "python"
string.upper()
# Out:
# 'PYTHON'

# %%
string = "hello world"
string.upper()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# ### 3. Convert a string to lowercase

# %%
string = "HELLO"
string.lower()
# Out:
# 'hello'

# %%
string = "Python3"
string.lower()
# Out:
# 'python3'

# %% [markdown]
# ### 4. Capitalize the first letter

# %%
string = "python programming"
string.capitalize()
# Out:
# 'Python programming'

# %%
string = "javaScript"
string.capitalize()
# Out:
# 'Javascript'

# %% [markdown]
# ### 5. Title case a string

# %%
string = "hello world"
string.title()
# Out:
# 'Hello World'

# %%
string = "python is fun"
string.title()
# Out:
# 'Python Is Fun'

# %% [markdown]
# ### 6. Count occurrences of a letter

# %%
string = "banana"
string.count("a")
# Out:
# 3

# %%
string = "mississippi"
string.count("s")
# Out:
# 4

# %% [markdown]
# ### 7. Replace a word in a string

# %%
string = "I like Java"
string.replace("Java", "Python")
# Out:
# 'I like Python'

# %%
string = "I live in USA"
string.replace("USA", "India")
# Out:
# 'I live in India'

# %% [markdown]
# ### 8. Check if a string starts with a specific word

# %%
string = "Hello World"
print(string.startswith('Hello'))
# Out:
# True

# %%
string = "Good Morning"
print(string.startswith("Morning"))
# Out:
# False

# %% [markdown]
# ### 9. Check if a string ends with a specific word

# %%
string = "program.py"
print(string.endswith(".py"))
# Out:
# True

# %%
string = "notes.txt"
print(string.endswith(".pdf"))
# Out:
# False

# %% [markdown]
# ### 10. Remove leading and trailing spaces

# %%
string = " hello "
string.strip()
# Out:
# 'hello'

# %%
string = " Python "
string.strip()
# Out:
# 'Python'

# %% [markdown]
# ### 11. Find the index of a character

# %%
string = "apple"
string.index("p")
# Out:
# 1

# %%
string = "banana"
string.index("n")
# Out:
# 2

# %% [markdown]
# ### 12. Extract the first three characters

# %%
string = "Python"
string[0 : 3]
# Out:
# 'Pyt'

# %%
string = "Computer"
string[0 : 3]
# Out:
# 'Com'

# %% [markdown]
# ### 13. Extract the last four characters

# %%
string = "Programming"
string[7 : ]
# Out:
# 'ming'

# %%
string = "Elephant"
string[4 : ]
# Out:
# 'hant'

# %% [markdown]
# ### 14. Reverse a string using slicing

# %%
string = "Python"
string[ : : -1]
# Out:
# 'nohtyP'

# %%
string = "apple"
string[ : : -1]
# Out:
# 'elppa'

# %% [markdown]
# ### 15. Extract characters from index 2 to 5

# %%
string = "Computer"
string[2 : 5]
# Out:
# 'mpu'

# %%
string = "Elephant"
string[2 : 5]
# Out:
# 'eph'

# %% [markdown]
# ### 16. Skip characters while slicing (step value)

# %%
string = "abcdef"
print(string[ : : 2])
# Out:
# ace

# %%
string = "123456789"
print(string[ : : 3])
# Out:
# 147

# %% [markdown]
# ### 17. Check if a substring exists

# %%
string = "Python Programming"
print("thon" in string)
# Out:
# True

# %%
string = "Data Science"
print("math" in string)
# Out:
# False

# %% [markdown]
# ### 18. Find the number of words in a string

# %%
string = "I love Python"
words = string.split()
print(len(words))
# Out:
# 3

# %%
string = "Data Science is fun"
words = string.split()
print(len(words))
# Out:
# 4

# %% [markdown]
# ### 19. Join a list of words into a string

# %%
listt = ["I", "love", "Python"]
string = ' '.join(listt)
print(string)
# Out:
# I love Python

# %%
listt = ["OpenAI", "GPT", "is", "cool"]
string = ' '.join(listt)
print(string)
# Out:
# OpenAI GPT is cool

# %% [markdown]
# ### 20. Split a string into a list of words

# %%
string = "OpenAI GPT"
listt = string.split()
print(listt)
# Out:
# ['OpenAI', 'GPT']

# %%
string = "Python Programming Language"
listt = string.split()
print(listt)
# Out:
# ['Python', 'Programming', 'Language']
